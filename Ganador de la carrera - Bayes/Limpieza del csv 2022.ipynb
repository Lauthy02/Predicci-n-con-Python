# %%
import pandas as pd

# Cargar el archivo CSV a la variable data
file_path = 'csvs_f1/formula1_2022season_raceResults.csv'
data = pd.read_csv(file_path)
print("---------- Data original ----------")
print(data)

# Saco las columnas que no me interesan
dataReducida = data.drop(['No','Team','Starting Grid','Laps','Time/Retired','Points','+1 Pt','Fastest Lap'], axis=1)
print("---------- Data reducida ----------")
print(dataReducida)

# Saco las filas que en la columna Position tienen NC
condicionNC = (data['Position'] != 'NC')
filasSinNC = dataReducida.loc[condicionNC]
print("---------- Data sin NC ----------")
print(filasSinNC)

# Los datos de la columna Position son de tipo string, los paso a int
filasSinNC['Position'] = pd.to_numeric(data['Position'], errors='coerce').astype('Int64')

# Agrego una nueva columna personalizada basado en una condición
# Quiero que cuando la columna Position sea 1, la columna Win sea 1, sino 0
condicionWIN1 = (filasSinNC['Position'] == 1)
condicionWIN0 = (filasSinNC['Position'] > 1)

# Creo la culumna Win 
filasSinNC['Win'] = " "

# Ejecuto las condiciones
filasSinNC.loc[condicionWIN1, 'Win'] = "1"
filasSinNC.loc[condicionWIN0, 'Win'] = "0"
dataConWIN = filasSinNC

print("---------- Data con win ----------")
print(dataConWIN)

dataConWIN.to_csv('csvs_f1_limpios/f1_data_limpia_2022.csv', index=False)
# Out:
# ---------- Data original ----------
#          Track Position  No           Driver               Team  \
# 0      Bahrain        1  16  Charles Leclerc            Ferrari
# 1      Bahrain        2  55     Carlos Sainz            Ferrari
# 2      Bahrain        3  44   Lewis Hamilton           Mercedes
# 3      Bahrain        4  63   George Russell           Mercedes
# 4      Bahrain        5  20  Kevin Magnussen       Haas Ferrari
# ..         ...      ...  ..              ...                ...
# 435  Abu Dhabi       16  47  Mick Schumacher       Haas Ferrari
# 436  Abu Dhabi       17  20  Kevin Magnussen       Haas Ferrari
# 437  Abu Dhabi       18  44   Lewis Hamilton           Mercedes
# 438  Abu Dhabi       19   6  Nicholas Latifi  Williams Mercedes
# 439  Abu Dhabi       NC  14  Fernando Alonso     Alpine Renault
#
#      Starting Grid  Laps Time/Retired  Points +1 Pt Fastest Lap
# 0                1    57  1:37:33.584      26   Yes    1:34.570
# 1                3    57       +5.598      18    No    1:35.740
# 2                5    57       +9.675      15    No    1:36.228
# 3                9    57      +11.211      12    No    1:36.302
# 4                7    57      +14.754      10    No    1:36.623
# ..             ...   ...          ...     ...   ...         ...
# 435             12    57       +1 lap       0    No    1:29.833
# 436             16    57       +1 lap       0    No    1:31.158
# 437              5    55          DNF       0    No    1:29.788
# 438             20    55          DNF       0    No    1:30.309
# 439             10    27          DNF       0    No    1:30.579
#
# [440 rows x 11 columns]
# ---------- Data reducida ----------
#          Track Position           Driver
# 0      Bahrain        1  Charles Leclerc
# 1      Bahrain        2     Carlos Sainz
# 2      Bahrain        3   Lewis Hamilton
# 3      Bahrain        4   George Russell
# 4      Bahrain        5  Kevin Magnussen
# ..         ...      ...              ...
# 435  Abu Dhabi       16  Mick Schumacher
# 436  Abu Dhabi       17  Kevin Magnussen
# 437  Abu Dhabi       18   Lewis Hamilton
# 438  Abu Dhabi       19  Nicholas Latifi
# 439  Abu Dhabi       NC  Fernando Alonso
#
# [440 rows x 3 columns]
# ---------- Data sin NC ----------
#          Track Position           Driver
# 0      Bahrain        1  Charles Leclerc
# 1      Bahrain        2     Carlos Sainz
# 2      Bahrain        3   Lewis Hamilton
# 3      Bahrain        4   George Russell
# 4      Bahrain        5  Kevin Magnussen
# ..         ...      ...              ...
# 434  Abu Dhabi       15  Valtteri Bottas
# 435  Abu Dhabi       16  Mick Schumacher
# 436  Abu Dhabi       17  Kevin Magnussen
# 437  Abu Dhabi       18   Lewis Hamilton
# 438  Abu Dhabi       19  Nicholas Latifi
#
# [376 rows x 3 columns]
# ---------- Data con win ----------
#          Track  Position           Driver Win
# 0      Bahrain         1  Charles Leclerc   1
# 1      Bahrain         2     Carlos Sainz   0
# 2      Bahrain         3   Lewis Hamilton   0
# 3      Bahrain         4   George Russell   0
# 4      Bahrain         5  Kevin Magnussen   0
# ..         ...       ...              ...  ..
# 434  Abu Dhabi        15  Valtteri Bottas   0
# 435  Abu Dhabi        16  Mick Schumacher   0
# 436  Abu Dhabi        17  Kevin Magnussen   0
# 437  Abu Dhabi        18   Lewis Hamilton   0
# 438  Abu Dhabi        19  Nicholas Latifi   0
#
# [376 rows x 4 columns]
# C:\Users\Lauta\AppData\Local\Temp\ipykernel_5536\2331232376.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filasSinNC['Position'] = pd.to_numeric(data['Position'], errors='coerce').astype('Int64')
# C:\Users\Lauta\AppData\Local\Temp\ipykernel_5536\2331232376.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filasSinNC['Win'] = " "
