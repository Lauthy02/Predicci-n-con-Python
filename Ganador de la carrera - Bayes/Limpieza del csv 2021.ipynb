# %%
import pandas as pd

# Cargar el archivo CSV a la variable data
file_path = 'csvs_f1/formula1_2021season_raceResults.csv'
data = pd.read_csv(file_path)
print("---------- Data original ----------")
print(data)

# Saco las columnas que no me interesan
dataReducida = data.drop(['No','Team','Starting Grid','Laps','Time/Retired','Points','+1 Pt','Fastest Lap'], axis=1)
print("---------- Data reducida ----------")
print(dataReducida)

# Saco las filas que en la columna Position tienen NC
condicionNC = (data['Position'] != 'NC')
filasSinNC = dataReducida.loc[condicionNC]
print("---------- Data sin NC ----------")
print(filasSinNC)

# Los datos de la columna Position son de tipo string, los paso a int
filasSinNC['Position'] = pd.to_numeric(data['Position'], errors='coerce').astype('Int64')

# Agrego una nueva columna personalizada basado en una condición
# Quiero que cuando la columna Position sea 1, la columna Win sea 1, sino 0
condicionWIN1 = (filasSinNC['Position'] == 1)
condicionWIN0 = (filasSinNC['Position'] > 1)

# Creo la culumna Win 
filasSinNC['Win'] = " "

# Ejecuto las condiciones
filasSinNC.loc[condicionWIN1, 'Win'] = "1"
filasSinNC.loc[condicionWIN0, 'Win'] = "0"
dataConWIN = filasSinNC

print("---------- Data con win ----------")
print(dataConWIN)

dataConWIN.to_csv('csvs_f1_limpios/f1_data_limpia_2021.csv', index=False)
# Out:
# ---------- Data original ----------
#          Track Position  No              Driver                       Team  \
# 0      Bahrain        1  44      Lewis Hamilton                   Mercedes
# 1      Bahrain        2  33      Max Verstappen      Red Bull Racing Honda
# 2      Bahrain        3  77     Valtteri Bottas                   Mercedes
# 3      Bahrain        4   4        Lando Norris           McLaren Mercedes
# 4      Bahrain        5  11        Sergio Perez      Red Bull Racing Honda
# ..         ...      ...  ..                 ...                        ...
# 435  Abu Dhabi       NC   6     Nicholas Latifi          Williams Mercedes
# 436  Abu Dhabi       NC  99  Antonio Giovinazzi  Alfa Romeo Racing Ferrari
# 437  Abu Dhabi       NC  63      George Russell          Williams Mercedes
# 438  Abu Dhabi       NC   7      Kimi Raikkönen  Alfa Romeo Racing Ferrari
# 439  Abu Dhabi       NC   9      Nikita Mazepin               Haas Ferrari
#
#      Starting Grid  Laps Time/Retired  Points +1 Pt Fastest Lap
# 0              2.0    56  1:32:03.897    25.0    No    1:34.015
# 1              1.0    56       +0.745    18.0    No    1:33.228
# 2              3.0    56      +37.383    16.0   Yes    1:32.090
# 3              7.0    56      +46.466    12.0    No    1:34.396
# 4             11.0    56      +52.047    10.0    No    1:33.970
# ..             ...   ...          ...     ...   ...         ...
# 435           16.0    50          DNF     0.0    No    1:29.293
# 436           14.0    33          DNF     0.0    No    1:29.442
# 437           17.0    26          DNF     0.0    No    1:30.647
# 438           18.0    25          DNF     0.0    No    1:29.698
# 439           20.0     0          DNS     0.0    No         NaN
#
# [440 rows x 11 columns]
# ---------- Data reducida ----------
#          Track Position              Driver
# 0      Bahrain        1      Lewis Hamilton
# 1      Bahrain        2      Max Verstappen
# 2      Bahrain        3     Valtteri Bottas
# 3      Bahrain        4        Lando Norris
# 4      Bahrain        5        Sergio Perez
# ..         ...      ...                 ...
# 435  Abu Dhabi       NC     Nicholas Latifi
# 436  Abu Dhabi       NC  Antonio Giovinazzi
# 437  Abu Dhabi       NC      George Russell
# 438  Abu Dhabi       NC      Kimi Raikkönen
# 439  Abu Dhabi       NC      Nikita Mazepin
#
# [440 rows x 3 columns]
# ---------- Data sin NC ----------
#          Track Position            Driver
# 0      Bahrain        1    Lewis Hamilton
# 1      Bahrain        2    Max Verstappen
# 2      Bahrain        3   Valtteri Bottas
# 3      Bahrain        4      Lando Norris
# 4      Bahrain        5      Sergio Perez
# ..         ...      ...               ...
# 430  Abu Dhabi       11  Sebastian Vettel
# 431  Abu Dhabi       12  Daniel Ricciardo
# 432  Abu Dhabi       13      Lance Stroll
# 433  Abu Dhabi       14   Mick Schumacher
# 434  Abu Dhabi       15      Sergio Perez
#
# [391 rows x 3 columns]
# ---------- Data con win ----------
#          Track  Position            Driver Win
# 0      Bahrain         1    Lewis Hamilton   1
# 1      Bahrain         2    Max Verstappen   0
# 2      Bahrain         3   Valtteri Bottas   0
# 3      Bahrain         4      Lando Norris   0
# 4      Bahrain         5      Sergio Perez   0
# ..         ...       ...               ...  ..
# 430  Abu Dhabi        11  Sebastian Vettel   0
# 431  Abu Dhabi        12  Daniel Ricciardo   0
# 432  Abu Dhabi        13      Lance Stroll   0
# 433  Abu Dhabi        14   Mick Schumacher   0
# 434  Abu Dhabi        15      Sergio Perez   0
#
# [391 rows x 4 columns]
# C:\Users\Lauta\AppData\Local\Temp\ipykernel_12840\950990184.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filasSinNC['Position'] = pd.to_numeric(data['Position'], errors='coerce').astype('Int64')
# C:\Users\Lauta\AppData\Local\Temp\ipykernel_12840\950990184.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filasSinNC['Win'] = " "
